# %% [markdown]
# # MNIST — Uncertainty Benchmark Results
#
# Visualise uncertainty estimates for the MNIST dataset acrosS subgroups:
# **blurring**, **thinning** and **fracture**.

# %%
import sys, importlib
sys.path.insert(0, '.')
import visuals
importlib.reload(visuals)
from visuals import *

# %%
load_results(
    experiments=['mnist_blur', 'mnist_fracture', 'mnist_thinning'],
    date_overrides={
        'mnist_blur':     '2026-06-17',
        'mnist_fracture': '2026-06-17',
        'mnist_thinning': '2026-06-17',
    },
)
# Out:
#   mnist_blur: /Users/sarasterlie/uncertainty-benchmark/results/2026-06-17/mnist_blur/18-22-53
#   mnist_fracture: /Users/sarasterlie/uncertainty-benchmark/results/2026-06-17/mnist_fracture/21-59-04
#   mnist_thinning: /Users/sarasterlie/uncertainty-benchmark/results/2026-06-17/mnist_thinning/23-13-46
# {'mnist_blur': PosixPath('/Users/sarasterlie/uncertainty-benchmark/results/2026-06-17/mnist_blur/18-22-53'),
#  'mnist_fracture': PosixPath('/Users/sarasterlie/uncertainty-benchmark/results/2026-06-17/mnist_fracture/21-59-04'),
#  'mnist_thinning': PosixPath('/Users/sarasterlie/uncertainty-benchmark/results/2026-06-17/mnist_thinning/23-13-46')}

# %% [markdown]
# ## MNIST Results
#
# Set `experiment` to any of: `mnist_blur`, `mnist_fracture`, `mnist_thinning`.
# Set `u_type` to any of: `total_uncertainty`, `aleatoric_uncertainty`, `epistemic_uncertainty`.

# %%
# Plot 1 — Per-method OOD uncertainty grid (epistemic, aleatoric & total overlaid)
plot_method_grid('mnist_thinning')
# Out:
# Saved → /Users/sarasterlie/uncertainty-benchmark/plots/method_grid_mnist_thinning.pdf

# %%
# Plot 2 — Sample distribution per OOD level
plot_distribution('mnist_fracture')
# Out:
# Saved → /Users/sarasterlie/uncertainty-benchmark/plots/distribution_mnist_fracture.pdf

# %%
# Plot 3 — OOD-detection AUROC line plot
plot_ood_auroc('mnist_fracture', u_type='epistemic_uncertainty')
# Out:
# Saved → /Users/sarasterlie/uncertainty-benchmark/plots/ood_auroc_mnist_fracture_epistemic_uncertainty.pdf
# /Users/sarasterlie/uncertainty-benchmark/src/visuals.py:273: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(title='Method', bbox_to_anchor=(1.01, 1), loc='upper left', fontsize=9)

# %%
# Plot 4 — Misclassification detection AUROC bar chart
plot_misclassification_auroc('mnist_fracture')
# Out:
# Saved → /Users/sarasterlie/uncertainty-benchmark/plots/misclassification_auroc_mnist_fracture.pdf
# /Users/sarasterlie/uncertainty-benchmark/src/visuals.py:376: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Method', y='AUROC', data=res, palette=palette_dict, ax=ax)
